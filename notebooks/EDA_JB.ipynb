# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Loading the data

# %%
import os
import pandas as pd

# %% [markdown]
# ## Load cleaned training set

# %%
path = "../raw_data/"

# %%
file_path = os.path.join(path, "train_df_ml_clean.csv")

data = pd.read_csv(file_path)


df = pd.DataFrame(data, columns=["label", "text",'clean_text'])
df["label"] = df["label"].astype(int)


df.head()
# Out:
#    label                                               text  \
# 0      1  Stuning even for the non-gamer: This sound tra...
# 1      1  The best soundtrack ever to anything.: I'm rea...
# 2      1  Amazing!: This soundtrack is my favorite music...
# 3      1  Excellent Soundtrack: I truly like this soundt...
# 4      1  Remember, Pull Your Jaw Off The Floor After He...
#
#                                           clean_text
# 0  stuning even for the nongamer this sound track...
# 1  the best soundtrack ever to anything im readin...
# 2  amazing this soundtrack is my favorite music o...
# 3  excellent soundtrack i truly like this soundtr...
# 4  remember pull your jaw off the floor after hea...

# %%
df.shape
# Out:
# (3600000, 3)

# %%
#This was accidently done twice. The labels are not -1 and 0 (does not affect model)
# Turn labels from 1 to 0 (bad) and 2 to 1 (good)
df.label = df['label'] - 1

# %% [markdown]
# ## Vectorize data and safe tfidf matrix locally

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000)

# %%
#Cleaning leads to some nan values
df = df.dropna()

# %%
X_train_full = vectorizer.fit_transform(df['clean_text'])

# %%
import joblib
joblib.dump(X_train_full, '../preprocessing_pipelines/tfidf_matrix.pkl')
# Out:
# ['../preprocessing_pipelines/tfidf_matrix.pkl']

# %%
X_train_full.shape
# Out:
# (3599990, 10000)

# %% [markdown]
# ## Create and train a model on 360k rows (10% of data)

# %%
X_train_reduced = X_train_full[:360000,:]

# %%
y_train_reduced = df.iloc[:360000,0]
y_train_reduced
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 359996   -1
# 359997   -1
# 359998   -1
# 359999    0
# 360000   -1
# Name: label, Length: 360000, dtype: int64

# %%
# Implement Logistic Regression with optimized params on 10% training set
max_features = 10000
logreg_C = 10

model = LogisticRegression(C=logreg_C, max_iter=1000)

model.fit(X_train_reduced, y_train_reduced)
# Out:
# LogisticRegression(C=10, max_iter=1000)

# %%
X_train_full[360001,:]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 44 stored elements and shape (1, 10000)>

# %%
df.iloc[360001,0]
# Out:
# np.int64(-1)

# %%
model.predict(X_train_full[360001,:])
# Out:
# array([-1])

# %% [markdown]
# ## Training on more data

# %%
#Splitting whole (vectorized) data into train and test
index = round(len(df) * 0.8)
X_train_final = X_train_full[:index,:]
X_test_final = X_train_full[index:,:]

y_train_final = df.iloc[:index,0]
y_test_final = df.iloc[index:,0]
index
# Out:
# 2879992

# %%
# Implement Logistic Regression with optimized params and learning curves on large training set
logreg_C = 10

model = LogisticRegression(C=logreg_C, max_iter=1000)

model.fit(X_train_final, y_train_final)
# Out:
# LogisticRegression(C=10, max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
y_pred = model.predict(X_test_final)
accuracy_score(y_test_final,y_pred)
# Out:
# 0.9223803399453887

# %% [markdown]
# ### Train a model on all 3.6M rows

# %%
logreg_C = 10

model = LogisticRegression(C=logreg_C, max_iter=1000)

model.fit(X_train_full, df['label'])
# Out:
# LogisticRegression(C=10, max_iter=1000)

# %% [markdown]
# ## Test the model on the real test data

# %%
test_df = pd.read_csv('../raw_data/raw_test_data.csv')

# %%
import string
import re
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
def clean_text(text):
    #No whitespaces in beginning or end
    text = text.strip()
    #lowercase
    text= text.lower()
    #remove numbers
    text = re.sub(r'\b\d+\b', '', text)

    text = re.sub(rf"[{re.escape(string.punctuation)}]", '', text)

    # Tokenizing
    tokenized = word_tokenize(text)
    # Lemmatizing
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(word) for word in tokenized]
    text = " ".join(lemmatized)
    return text

# %%
#Clean and vectorize test data
test_df['clean_text'] = test_df['text'].apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[137], line 2
#       1 #Clean and vectorize test data
# ----> 2 test_df['clean_text'] = test_df['text'].apply(clean_text)
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/pandas/core/series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)
#    4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)
#    4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[136], line 15, in clean_text(text)
#      13 # Lemmatizing
#      14 lemmatizer = WordNetLemmatizer()
# ---> 15 lemmatized = [lemmatizer.lemmatize(word) for word in tokenized]
#      16 text = " ".join(lemmatized)
#      17 return text
#
# Cell In[136], line 15, in <listcomp>(.0)
#      13 # Lemmatizing
#      14 lemmatizer = WordNetLemmatizer()
# ---> 15 lemmatized = [lemmatizer.lemmatize(word) for word in tokenized]
#      16 text = " ".join(lemmatized)
#      17 return text
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/nltk/stem/wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)
#      83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/nltk/stem/wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)
#      37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/nltk/corpus/reader/wordnet.py:2109, in WordNetCorpusReader._morphy(self, form, pos, check_exceptions)
#    2106     forms = apply_rules([form])
#    2108 # 2. Return all that are in the database (and check the original too)
# -> 2109 return filter_forms([form] + forms)
#
# File ~/.pyenv/versions/3.10.6/envs/sentiscope/lib/python3.10/site-packages/nltk/corpus/reader/wordnet.py:2095, in WordNetCorpusReader._morphy.<locals>.filter_forms(forms)
#    2093 for form in forms:
#    2094     if form in self._lemma_pos_offset_map:
# -> 2095         if pos in self._lemma_pos_offset_map[form]:
#    2096             if form not in seen:
#    2097                 result.append(form)
#
# KeyboardInterrupt:

# %%
#Adjust labels. Maybe you have to execute this cell twice
test_df['label'] = test_df['label'] -1

# %%
test_df.head(3)
# Out:
#    label                                               text  \
# 0      0  Great CD: My lovely Pat has one of the GREAT v...
# 1      0  One of the best game music soundtracks - for a...
# 2     -1  Batteries died within a year ...: I bought thi...
#
#                                           clean_text
# 0  great cd my lovely pat ha one of the great voi...
# 1  one of the best game music soundtrack for a ga...
# 2  battery died within a year i bought this charg...

# %%
X_test = vectorizer.transform(test_df['clean_text'])

# %%
#Use previously trained model to predict test labels
y_test = test_df['label']
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9214275

# %%
#Adjust labels to test precision and recall

y_pred = y_pred + 1

# %%
#Adjusting test labels
y_test = y_test +1

# %%
precision_score(y_test, y_pred), recall_score(y_test, y_pred)
# Out:
# (0.9199304479530473, 0.92321)

# %%
#Save vectorized test set
joblib.dump(X_test, '../preprocessing_pipelines/test_tfidf_matrix.pkl')
# Out:
# ['../preprocessing_pipelines/test_tfidf_matrix.pkl']

# %% [markdown]
# ### Saving model locally

# %%
from datetime import datetime

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
model_path = f"../model/logreg_full_model_{timestamp}.pkl"
joblib.dump(model, model_path)
print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ../model/logreg_full_model_20250610_1746.pkl

# %%
X_train_full.shape
# Out:
# (3599990, 10000)

# %%
df['label'].shape
# Out:
# (3599990,)

# %%
import dill
import pickle

# %%
import pandas as pd
import numpy as np
import os

#Basic cleaning
import string
import re

#ML tokenizing, lemmatizing and vectorizing
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
def preprocess_series(X):
        """
        Helper function for pipeline
        This function always has to be available in the namespace when loading
        the pipeline.
        """
        def basic_cleaning(text):
            """
            Function which takes a string and cleans it to get the string ready for
            future preprocessing. This is a universal step which the data will always
            undergo.
            Input: String
            Output: String
            """

            #No whitespaces in beginning or end
            text = text.strip()

            #lowercase
            text= text.lower()

            #remove numbers
            text = re.sub(r'\b\d+\b', '', text)

            #Removing punctuation
            text = re.sub(rf"[{re.escape(string.punctuation)}]", '', text)

            # Tokenizing
            tokenized = word_tokenize(text)

            # Lemmatizing
            lemmatizer = WordNetLemmatizer()
            lemmatized = [lemmatizer.lemmatize(word) for word in tokenized]

            text = " ".join(lemmatized)
            return text

        return[basic_cleaning(text) for text in X]

# %%
with open("/Users/johannesb/code/Jojo2813/SentiScope/preprocessing_pipelines/preproc_pipeline_ml.pkl",'rb') as f:
    pipe = pickle.load(f)

# %%
# Ensure full recursive serialization
dill.settings['recurse'] = True

# %%
with open("/Users/johannesb/code/Jojo2813/SentiScope/model/preproc_pipeline_ml_2.pkl", "wb") as f:
    dill.dump(pipe, f)
